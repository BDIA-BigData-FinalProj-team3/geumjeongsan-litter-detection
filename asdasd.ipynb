# %%
import pandas as pd

# %%
df = pd.read_csv("./clean_optionB_300.csv")

# %%
df
# Out:
#     segment_id segment_name segment_type        start_x        start_y  \
# 0    TRAIL-001        금정로 1      금정로 1-1  207506.115596  291321.975419
# 1    TRAIL-002        금정로 2      금정로 2-1  205071.373799  294917.782961
# 2    TRAIL-003        금정로 2      금정로 2-2  204659.515574  295689.367692
# 3    TRAIL-004        금정로 3      금정로 3-1  204600.874042  298101.222625
# 4    TRAIL-005        금정로 4      금정로 4-1  203628.510463  303987.585513
# ..         ...          ...          ...            ...            ...
# 295  TRAIL-296       금정로 75     금정로 75-6  204543.111467  297488.237878
# 296  TRAIL-297       금정로 75     금정로 75-7  204162.739763  296978.878995
# 297  TRAIL-298       금정로 75     금정로 75-8  204537.576130  296255.835693
# 298  TRAIL-299       금정로 76     금정로 76-1  205911.673909  296348.304164
# 299  TRAIL-300       금정로 76     금정로 76-2  206775.663968  296514.339167
#
#              end_x          end_y   start_lon  start_lat     end_lon  \
# ...

# %%
aaa = pd.read_csv("./금정산_등산로_이름추가.csv")

# %%
aaa
# Out:
#     segment_id segment_name segment_type        start_x        start_y  \
# 0    TRAIL-001        금정로 1      금정로 1-1  207506.115596  291321.975419
# 1    TRAIL-002        금정로 2      금정로 2-1  205071.373799  294917.782961
# 2    TRAIL-003        금정로 2      금정로 2-2  204659.515574  295689.367692
# 3    TRAIL-004        금정로 3      금정로 3-1  204600.874042  298101.222625
# 4    TRAIL-005        금정로 4      금정로 4-1  203628.510463  303987.585513
# ..         ...          ...          ...            ...            ...
# 295  TRAIL-296       금정로 75     금정로 75-6  204543.111467  297488.237878
# 296  TRAIL-297       금정로 75     금정로 75-7  204162.739763  296978.878995
# 297  TRAIL-298       금정로 75     금정로 75-8  204537.576130  296255.835693
# 298  TRAIL-299       금정로 76     금정로 76-1  205911.673909  296348.304164
# 299  TRAIL-300       금정로 76     금정로 76-2  206775.663968  296514.339167
#
#              end_x          end_y   start_lon  start_lat     end_lon  \
# ...
